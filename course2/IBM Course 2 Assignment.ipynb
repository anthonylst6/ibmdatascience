# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Anthony Liu**
# My current desired occupation is a Data Science or Data Analyst, ideally within a space i'm passionate about such as renewable energy, public services or health. Further down my career I am even interested in learning Machine Learning and Artificial Intelligence to qualify for research positions or occupations involving innovative applications of AI.

# %% [markdown]
# *I am interested in data science because it involves a high level of analytic thought, presents an enjoyable challenge and has really exciting applicatons especially with the advent of artificial intelligence.*

# %% [markdown]
# ### The following cell assigns the value 1 to the variable x and the value 2 to the variable y, then prints the addition of the two assigned variables.

# %%
x = 1
y = 2
print(x+y)
# Out:
# 3

# %% [markdown]
# A horizontal rule can be made using three consecutive asterisks:
#
# ***
#
# A bulleted list can be made using single asterisks followed by entries:
# * Item 1
# * Item 2
# * Item 3
#
# A numbered list can be made simply by using digits followed by a period:
# 1. Numbered item 1
# 2. Numbered item 2
# 3. Numbered item 3
#
# You can even make tables using markdown:
#
# | Heading 1 | Heading 2 | Heading 3 |
# | :---: | :---: | :---: |
# | Entry 1 | Entry 2 | Entry 3 |
#
# [Here is a hyperlink to Coursera](https://www.coursera.org/ "Coursera")
#
# Here is a fancy version of the IBM Logo: ![alt text](https://www.ibm.com/design/language/a5f697ca92957d0b7e4ec88dd080a26c/rebus-black.svg "Fancy IBM Logo")
#
# The code in the previous cell was:
#
# ```
# x = 1
# y = 2
# print(x+y)
# ```
#
# > Here are some
# > blocked quotes
#
# And finally, here is some ~~strikethrough~~
