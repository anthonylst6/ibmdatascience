# %% [markdown]
# # Capstone Project - IBM Data Science
#
# This notebook is part of the Capstone Project of the IBM Data Science Professional Certificate

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
CLIENT_ID = 'ZGMWE0F5NFNKSPS1NTGJCLUWQRKW1SIDN0143DK0ZMCE3G3D'
CLIENT_SECRET = 'NWJYE11CG3B2DCKGM0OCFN11KCB53KITLTEXSPGJL4QDGAMT'
ACCESS_TOKEN = 'OISRZIBHSE0NS5KSQT1QR1A2XMM3BOUWMSXRKSCHANJ4E3CL'
VERSION = '20200216'

# %%
# Import necessary libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import wget
import os.path
from os import path
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import json
from pandas.io.json import json_normalize
import folium

# %%
# Download the file containing geographical coordinates of Australian postcodes if it doesn't exist
if path.exists('australian_postcodes.csv') == False:
    url = 'https://www.matthewproctor.com/Content/postcodes/australian_postcodes.csv'
    wget.download(url)
geo = pd.read_csv("australian_postcodes.csv")[['postcode', 'locality', 'lat', 'long']] # Read in relevant columns of file
geo = geo.dropna() # Remove rows with NAs
geo = geo[(geo.lat > -34.13) & (geo.lat < -33.57) & (geo.long > 150.60) & (geo.long < 151.35)] # Select only those rows that are in Sydney area
geoleft = geo.groupby(['postcode'])['locality'].apply(', '.join).reset_index() # Combine localities within same postcode
georight = geo.groupby(['postcode'])['lat', 'long'].mean().reset_index() # Average latitudes and longitudes for multiple localities in same postcode
geo = pd.merge(left = geoleft, right = georight, left_on = 'postcode', right_on = 'postcode') # Merge back into single dataframe
print('Shape of dataframe:', geo.shape) # Find shape of resulting dataframe
geo.head() # Preview resulting dataframe
# Out:
# Shape of dataframe: (476, 4)
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   if __name__ == '__main__':
#    postcode locality        lat        long
# 0      1001   SYDNEY -33.794883  151.268071
# 1      1002   SYDNEY -33.794883  151.268071
# 2      1003   SYDNEY -33.794883  151.268071
# 3      1004   SYDNEY -33.794883  151.268071
# 4      1005   SYDNEY -33.794883  151.268071

# %%
# Download the file containing solar installation data by postcode in Australia if it doesn't exist
if path.exists('postcodes_1618.csv') == False:
    url = 'https://d284f79vx7w9nf.cloudfront.net/attachments/analysis/5/postcodes_1618.csv'
    wget.download(url)
pv = pd.read_csv("postcodes_1618.csv")[['postcode', 'capacity', 'pot_kw']] # Read in relevant columns of file
pv = pv.dropna().astype({'postcode' : int}) # Remove rows with NAs and convert postcode to integer format
print('Shape of dataframe:', pv.shape) # Find shape of resulting dataframe
pv.head() # Preview resulting dataframe
# Out:
# Shape of dataframe: (2605, 3)
#    postcode  capacity    pot_kw
# 0       800    1943.0   32376.0
# 1       810   15648.0  198075.0
# 2       812    7638.0  101247.0
# 3       820   13470.0  188975.0
# 4       822   12360.0  140603.0

# %%
df = pd.merge(left = geo, right = pv, left_on = "postcode", right_on = "postcode") # Merge the two dataframes (via inner join)
print('Shape of dataframe:', df.shape) # Find shape of resulting dataframe
df.head() # Preview resulting dataframe
# Out:
# Shape of dataframe: (220, 6)
#    postcode                                           locality        lat  \
# 0      2000  BARANGAROO, DARLING HARBOUR, DAWES POINT, HAYM... -33.860016
# 1      2007                                   BROADWAY, ULTIMO -33.883189
# 2      2008              CHIPPENDALE, DARLINGTON, GOLDEN GROVE -33.891146
# 3      2009                            DARLING ISLAND, PYRMONT -33.871222
# 4      2010           DARLINGHURST, SURRY HILLS, TAYLOR SQUARE -33.884119
#
#          long  capacity   pot_kw
# 0  151.250530    2097.0  56265.0
# 1  151.196650     144.0  16683.0
# 2  151.193858     632.0  19225.0
# 3  151.193055     907.0  18489.0
# 4  151.212262     919.0  55246.0

# %%
# Find geographical coordinates of Sydney, Australia
address = 'Sydney'
geolocator = Nominatim(user_agent="syd_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Sydney are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Sydney are -33.8548157, 151.2164539.

# %%
# Create map of Sydney using latitude and longitude values
map_syd = folium.Map(location = [latitude, longitude], zoom_start = 10)

# Add markers to map
for postcode, locality, lat, long in zip(df['postcode'], df['locality'], df['lat'], df['long']):
    label = 'Postcode: {} (Contains suburbs: {})'.format(postcode, locality)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, long],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = '#3186cc',
        fill_opacity = 0.7,
        parse_html = False).add_to(map_syd)  

# View the map
map_syd
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
LIMIT = 20
radius = 1000

def gettipcounts(postcode, lat, long, radius = radius):
    
    tipcounts_list = []
    for postcode, lat, long in zip(postcode, lat, long):
            
        # create the API request URL
        url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&oauth_token={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            ACCESS_TOKEN, 
            VERSION, 
            lat, 
            long, 
            radius, 
            LIMIT)
            
        # make the GET request
        try:
            results1 = requests.get(url1).json()["response"]['groups'][0]['items']
        except:
            continue
        
        # return only relevant information for each nearby venue
        for v in results1:
            venue_id = v['venue']['id']
            url2 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(
                venue_id,
                CLIENT_ID,
                CLIENT_SECRET,
                ACCESS_TOKEN,
                VERSION)
            try:
                results2 = requests.get(url2).json()['response']['venue']
            except:
                continue
            tipcounts_list.append([
                postcode,
                results2['name'],
                results2['tips']['count']
            ])
        
    tip_counts = pd.DataFrame([item for tipcount_list in tipcounts_list for item in tipcount_list])
    tip_counts.columns = ['postcode', 
                  'venue', 
                  'tipcounts']
    
    return(tip_counts)

# %%
sydney_tipcounts = gettipcounts(postcode = df['postcode'],
                                   lat = df['lat'],
                                   long = df['long']
                                  )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-f3119cd114b1> in <module>
#       1 sydney_tipcounts = gettipcounts(postcode = df['postcode'],
#       2                                    lat = df['lat'],
# ----> 3                                    long = df['long']
#       4                                   )
#
# <ipython-input-43-63e91756b532> in gettipcounts(postcode, lat, long, radius)
#      19
#      20         # make the GET request
# ---> 21         results1 = requests.get(url1).json()["response"]['groups'][0]['items']
#      22
#      23         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %%
print('Shape of dataframe:', sydney_tipcounts.shape)
sydney_tipcounts.head()

# %%
tip = sydney_tipcounts.groupby(['postcode'])['tipcounts'].sum().reset_index()
df_final = pd.merge(left = df, right = tip, left_on = 'postcode', right_on = 'postcode') # Merge the two dataframes (via inner join)
print('Shape of dataframe:', df_final.shape) # Find shape of resulting dataframe
df_final.head() # Preview resulting dataframe

# %%
lat = -33.860016
long = 151.250530
LIMIT = 20
radius = 1000

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&oauth_token={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            ACCESS_TOKEN, 
            VERSION, 
            lat, 
            long, 
            radius, 
            LIMIT)

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e4a5e4b02a172001b27df7e'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 9,
#   'suggestedBounds': {'ne': {'lat': -33.85101599099999,
#     'lng': 151.26134790801675},
#    'sw': {'lat': -33.86901600900001, 'lng': 151.23971209198325}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdbd2353904a593e1364c9e',
#        'name': 'Shark Island',
#        'location': {'address': 'Shark Island',
#         'lat': -33.85832449057107,
#         'lng': 151.25783702274848,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.85832449057107,
#           'lng': 151.25783702274848}],
#         'distance': 701,
#         'cc': 'AU',
#         'city': 'Sydney',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ['Shark Island', 'Sydney NSW']},
#        'categories': [{'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'shortName': 'Harbor / Marina',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdbd2353904a593e1364c9e-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3c5fc9f964a520178425e3',
#        'name': "Bradley's Head",
#        'location': {'address': "Bradley's Head Rd",
#         'lat': -33.853210359228804,
#         'lng': 151.24625863138664,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.853210359228804,
#           'lng': 151.24625863138664}],
#         'distance': 854,
#         'cc': 'AU',
#         'city': 'Mosman',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ["Bradley's Head Rd", 'Mosman NSW']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3c5fc9f964a520178425e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4baf10cbf964a5208de93be3',
#        'name': 'Royal Motor Yacht Club',
#        'location': {'address': '21 Wunulla Rd.',
#         'lat': -33.867104818306,
#         'lng': 151.25441696040335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.867104818306,
#           'lng': 151.25441696040335}],
#         'distance': 867,
#         'postalCode': '2027',
#         'cc': 'AU',
#         'city': 'Point Piper',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ['21 Wunulla Rd.', 'Point Piper NSW 2027']},
#        'categories': [{'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'shortName': 'Harbor / Marina',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4baf10cbf964a5208de93be3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b089cc6f964a5206c0f23e3',
#        'name': 'Duff Reserve',
#        'location': {'address': 'Wolseley Road',
#         'lat': -33.864291482973165,
#         'lng': 151.25102212493914,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.864291482973165,
#           'lng': 151.25102212493914}],
#         'distance': 478,
#         'cc': 'AU',
#         'neighborhood': 'Eastern Suburbs',
#         'city': 'Point Piper',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ['Wolseley Road', 'Point Piper NSW']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b089cc6f964a5206c0f23e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b218facf964a520f83d24e3',
#        'name': 'Royal Prince Edward Yacht Club',
#        'location': {'address': '160 Wolseley Rd.',
#         'lat': -33.86528,
#         'lng': 151.25312,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.86528,
#           'lng': 151.25312}],
#         'distance': 633,
#         'postalCode': '2027',
#         'cc': 'AU',
#         'city': 'Point Piper',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ['160 Wolseley Rd.', 'Point Piper NSW 2027']},
#        'categories': [{'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'shortName': 'Harbor / Marina',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b218facf964a520f83d24e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55230c83498ecee05b0427ed',
#        'name': 'Manly Fast Ferry - Fantasea',
#        'location': {'address': 'East Esplanade',
#         'lat': -33.85378094165202,
#         'lng': 151.2496216056002,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.85378094165202,
#           'lng': 151.2496216056002}],
#         'distance': 699,
#         'cc': 'AU',
#         'country': 'Australia',
#         'formattedAddress': ['East Esplanade']},
#        'categories': [{'id': '4bf58dd8d48988d12d951735',
#          'name': 'Boat or Ferry',
#          'pluralName': 'Boats or Ferries',
#          'shortName': 'Boat / Ferry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55230c83498ecee05b0427ed-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b80b5caf964a5209c8730e3',
#        'name': "Watson's Bay Ferry",
#        'location': {'address': 'Water',
#         'lat': -33.860495923989625,
#         'lng': 151.2426135007629,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.860495923989625,
#           'lng': 151.2426135007629}],
#         'distance': 733,
#         'cc': 'AU',
#         'city': 'Sydney',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ['Water', 'Sydney NSW']},
#        'categories': [{'id': '4bf58dd8d48988d12d951735',
#          'name': 'Boat or Ferry',
#          'pluralName': 'Boats or Ferries',
#          'shortName': 'Boat / Ferry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b80b5caf964a5209c8730e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52b7d78b498ea1b65e7354ad',
#        'name': 'Bradleys Head Amphitheatre',
#        'location': {'address': 'Ashton Park',
#         'lat': -33.8534527401253,
#         'lng': 151.24603271484375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.8534527401253,
#           'lng': 151.24603271484375}],
#         'distance': 840,
#         'cc': 'AU',
#         'city': 'Mosman, NSW, Australia',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ['Ashton Park', 'Mosman NSW']},
#        'categories': [{'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'shortName': 'Music Venue',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52b7d78b498ea1b65e7354ad-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c34fb5b452620a1f30c260f',
#        'name': 'Clark Island',
#        'location': {'address': 'Clark Island',
#         'lat': -33.862860838931546,
#         'lng': 151.24085440672752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.862860838931546,
#           'lng': 151.24085440672752}],
#         'distance': 948,
#         'postalCode': '2000',
#         'cc': 'AU',
#         'city': 'Sydney',
#         'state': 'NSW',
#         'country': 'Australia',
#         'formattedAddress': ['Clark Island', 'Sydney NSW 2000']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c34fb5b452620a1f30c260f-8'}]}]}}

# %%
venue_id = results['response']['groups'][0]['items'][0]['venue']['id']

# %%
url2 = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&oauth_token={}&v={}'.format(
    venue_id,
    CLIENT_ID,
    CLIENT_SECRET,
    ACCESS_TOKEN,
    VERSION)

# %%
result2 = requests.get(url2).json()

# %%
result2['response']['venue']['tips']['count']
# Out:
# 2

# %%
result2['response']['venue']
# Out:
# {'id': '4bdbd2353904a593e1364c9e',
#  'name': 'Shark Island',
#  'contact': {},
#  'location': {'address': 'Shark Island',
#   'lat': -33.85832449057107,
#   'lng': 151.25783702274848,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': -33.85832449057107,
#     'lng': 151.25783702274848}],
#   'cc': 'AU',
#   'city': 'Sydney',
#   'state': 'NSW',
#   'country': 'Australia',
#   'formattedAddress': ['Shark Island', 'Sydney NSW']},
#  'canonicalUrl': 'https://foursquare.com/v/shark-island/4bdbd2353904a593e1364c9e',
#  'categories': [{'id': '4bf58dd8d48988d1e0941735',
#    'name': 'Harbor / Marina',
#    'pluralName': 'Harbors / Marinas',
#    'shortName': 'Harbor / Marina',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d163941735',
#    'name': 'Park',
#    'pluralName': 'Parks',
#    'shortName': 'Park',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#     'suffix': '.png'}}],
#  'verified': False,
#  'stats': {'tipCount': 2},
#  'likes': {'count': 12,
#   'groups': [{'type': 'others', 'count': 12, 'items': []}],
#   'summary': '12 Likes'},
#  'like': False,
#  'dislike': False,
#  'ok': False,
#  'rating': 8.2,
#  'ratingColor': '73CF42',
#  'ratingSignals': 15,
#  'venueRatingBlacklisted': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 72,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 72,
#     'items': [{'id': '502f2133e4b045150a9ca2b3',
#       'createdAt': 1345265971,
#       'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/neSeEX1Wkutd5dEWgxH_R4Lb8o82weTYqYrLPVPbU0M.jpg',
#       'width': 612,
#       'height': 612,
#       'user': {'id': '1381283',
#        'firstName': 'Thomas',
#        'lastName': 'Vong',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/KDTX4GZX4BNZ2JL0.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1272697397,
#  'tips': {'count': 2,
#   'groups': [{'type': 'following',
#     'name': 'Tips from people you follow',
#     'count': 0,
#     'items': []},
#    {'type': 'others',
#     'name': 'All tips',
#     'count': 2,
#     'items': [{'id': '5868a22053f5bb395e5d417d',
#       'createdAt': 1483252256,
#       'text': 'Great spot to watch NYE fireworks!',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5868a22053f5bb395e5d417d',
#       'likes': {'count': 0, 'groups': []},
#       'like': False,
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '3147886',
#        'firstName': 'Keith',
#        'lastName': 'Greywood',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/FDDKMY1L3IZVVVMB.jpg'}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/aaJnc0',
#  'timeZone': 'Australia/Sydney',
#  'listed': {'count': 8,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 8,
#     'items': [{'id': '567a8a7e498e50c784034993',
#       'name': 'Sydney to do',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '13799858',
#        'firstName': 'Bingo',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/MSFIGL4WQHM41LMD.png'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/bingorus/list/sydney-to-do',
#       'canonicalUrl': 'https://foursquare.com/bingorus/list/sydney-to-do',
#       'createdAt': 1450871422,
#       'updatedAt': 1454428411,
#       'photo': {'id': '51751793e4b00121ffc9cd14',
#        'createdAt': 1366628243,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1143186_0qoGd3UVGnsY3M48siEfAfIe-bSyXubipngCCpxO_y8.jpg',
#        'width': 612,
#        'height': 612,
#        'user': {'id': '1143186',
#         'firstName': 'Priska',
#         'lastName': 'Raharjo',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/GNRKYA0IAKUDMWXK.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 0},
#       'listItems': {'count': 45,
#        'items': [{'id': 'v4bdbd2353904a593e1364c9e',
#          'createdAt': 1450975383,
#          'photo': {'id': '565d2111498e97531f1f3a66',
#           'createdAt': 1448943889,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/1720934_WpQNOjHs0s2e52m_7V8IQTUqPt4RocrbMXI4TnbNdsQ.jpg',
#           'width': 1920,
#           'height': 1440,
#           'user': {'id': '1720934',
#            'firstName': 'Simon',
#            'lastName': 'Crerar',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/1720934-QWPVAMNBNTOQTFFH.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4ea91348775bdf7c38638574',
#       'name': 'Sydney life',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '22026',
#        'firstName': 'David',
#        'lastName': 'Rohrsheim',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/RSSMBQM12Y1UIGI4.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/rohrsh/list/sydney-life',
#       'canonicalUrl': 'https://foursquare.com/rohrsh/list/sydney-life',
#       'createdAt': 1319703368,
#       'updatedAt': 1554838788,
#       'photo': {'id': '4e4625dcd4c065cb6b9bc730',
#        'createdAt': 1313220060,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/ER1ZI51ZDAI1ZQ42HVU0EHRM10EZJS1RFLFRWW3IONQENXSE.jpg',
#        'width': 540,
#        'height': 540,
#        'user': {'id': '3275974',
#         'firstName': 'Justine',
#         'lastName': 'Bloome',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/3275974-WSUHN3QJDSRRZK3S'}},
#        'visibility': 'public'},
#       'followers': {'count': 44},
#       'listItems': {'count': 114,
#        'items': [{'id': 't4c9ff321e9a7ef3b07814c16',
#          'createdAt': 1319704824,
#          'tip': {'id': '4c9ff321e9a7ef3b07814c16',
#           'createdAt': 1285550881,
#           'text': "Sydney Harbour Island Hopping throughout October which is also part of the Crave Sydney International Food Festival. Let the kids have a go at being a 'Future Ranger' here.",
#           'type': 'user',
#           'url': 'http://www.harbourislandhopping.com/',
#           'canonicalUrl': 'https://foursquare.com/item/4c9ff321e9a7ef3b07814c16',
#           'likes': {'count': 0, 'groups': []},
#           'like': False,
#           'logView': True,
#           'agreeCount': 0,
#           'disagreeCount': 0,
#           'todo': {'count': 0},
#           'saves': {},
#           'user': {'id': '3584802',
#            'firstName': 'Crave',
#            'lastName': 'Sydney',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/1JI4PXS4NJLASE2H.jpg'}}},
#          'photo': {'id': '4e6c1d257d8b2c711b25c187',
#           'createdAt': 1315708197,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/CZYEXMSYXNC2LTO4UXC0EYVFA3G1RKRUMHXQZY2FOPA5AQIJ.jpg',
#           'width': 720,
#           'height': 537,
#           'user': {'id': '11483617',
#            'firstName': 'Ciaran',
#            'lastName': 'Burke',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/BCPI3XILNNZCGAZ0.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': []},
#  'bestPhoto': {'id': '502f2133e4b045150a9ca2b3',
#   'createdAt': 1345265971,
#   'source': {'name': 'Instagram', 'url': 'http://instagram.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/neSeEX1Wkutd5dEWgxH_R4Lb8o82weTYqYrLPVPbU0M.jpg',
#   'width': 612,
#   'height': 612,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '502f2133e4b045150a9ca2b3',
#    'value': -13615016},
#   'highlightTextColor': {'photoId': '502f2133e4b045150a9ca2b3', 'value': -1},
#   'algoVersion': 3}}

# %%
venue_id
# Out:
# '4bdbd2353904a593e1364c9e'

# %%
x = results['response']['groups'][0]['items']

# %%
for result in x:
    venue_id = result['venue']['id']
    print(venue_id)
# Out:
# 4bdbd2353904a593e1364c9e
# 4b3c5fc9f964a520178425e3
# 4baf10cbf964a5208de93be3
# 4b089cc6f964a5206c0f23e3
# 4b218facf964a520f83d24e3
# 55230c83498ecee05b0427ed
# 4b80b5caf964a5209c8730e3
# 52b7d78b498ea1b65e7354ad
# 4c34fb5b452620a1f30c260f
